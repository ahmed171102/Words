# %%
import kagglehub
import shutil
import os

# 1. Download the dataset (Kagglehub handles the heavy lifting and caching)
print("Initiating download... Grab a coffee, this might take a while! ☕")
cache_path = kagglehub.dataset_download("yousefdotpy/karsl-502")
print(f"Download complete! Temporarily cached at: {cache_path}")

# 2. Define where you actually want it on your PC (e.g., a folder named 'karsl_dataset' right next to this notebook)
project_path = "./karsl_dataset"

# 3. Copy the files from the hidden cache to your working directory
print(f"Transferring files to your project folder ({project_path})...")
shutil.copytree(cache_path, project_path, dirs_exist_ok=True)

print("All done! Your KArSL dataset is ready for processing.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import kagglehub
#       2 import shutil
#       3 import os
#
# ModuleNotFoundError: No module named 'kagglehub'
